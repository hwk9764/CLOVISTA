# %%
import os
import json
import pandas as pd
import pytz
from datetime import datetime
from sqlalchemy import create_engine

# %%
# 접속 정보
host = "10.28.224.177"
port = 30634
database = "postgres"
username = "postgres"
password = "0104"

# %%
# SQLAlchemy 엔진 생성
engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# %% [markdown]
# # 유튜브 데이터 DB에 저장

# %% [markdown]
# ### channel

# %%
channel_lst = ["donghahahaha", "metacomedyclub", "dannychocomedy", "one_liner_comic", "KoreanCryingGuy", "ChimChakMan_Official"] 
channel_name = ['동하하', '메타코미디클럽', '대니초', '원라이너', '유병재', '침착맨']

# %%
columns_name = ['id', 'name' , 'DisplayName', 'uId', 'title', 'description', 'publishedAt', 'thumbnails', 'viewCount', 'subscriberCount', 'videoCount', 'topicCategories', 'dataTime']

# %%
# 한국 시간대 설정
korea_timezone = pytz.timezone('Asia/Seoul')

# 현재 시간 가져오기
korea_time = datetime.now(korea_timezone)

# 원하는 형식으로 출력 (YYYY-MM-DD)
formatted_time = korea_time.strftime('%Y-%m-%d')

# %%
result = []
for name, channel in zip(channel_name, channel_lst):
    with open('./'+ channel + '/' + 'chanel_info.json', 'r', encoding='utf-8') as file:
        data = json.load(file)
    print(data)
    items = data['items']
    uId = items[0]['id']
    title = items[0]['snippet']['title']
    description = items[0]['snippet']['description']
    publishedAt = items[0]['snippet']['publishedAt']
    thumbnails = items[0]['snippet']['thumbnails']['default']['url']
    viewCount = items[0]['statistics']['viewCount']
    subscriberCount = items[0]['statistics']['subscriberCount']
    videoCount = items[0]['statistics']['videoCount']
    topicCategories = items[0]['topicDetails']['topicCategories']
    dataTime = formatted_time
    result.append([name, '@'+channel, uId, title, description, publishedAt, thumbnails, viewCount, subscriberCount, videoCount, topicCategories, dataTime])
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'fpqsuRf2NzUgSiKROTIrFxInsLc', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'dCBbVDw_A4eNhJ9uXEgsO-cOyRc', 'id': 'UC_VSHnyAnKnljt3iMYd8H3w', 'snippet': {'title': '동하하', 'description': '놀림전문가\n\n섭외 문의 \n이메일 - dongha@metacomedy.net \n인스타 - donghahahaha DM', 'customUrl': '@donghahahaha', 'publishedAt': '2012-08-18T09:35:10Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/XiAkIp5pc-l0I6tzZpbQeZr2l0_BBbrnjdjY_TNPqITk6R9WtSiWInmPYlX_jIzvXCojiQRucQ=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/XiAkIp5pc-l0I6tzZpbQeZr2l0_BBbrnjdjY_TNPqITk6R9WtSiWInmPYlX_jIzvXCojiQRucQ=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/XiAkIp5pc-l0I6tzZpbQeZr2l0_BBbrnjdjY_TNPqITk6R9WtSiWInmPYlX_jIzvXCojiQRucQ=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': '동하하', 'description': '놀림전문가\n\n섭외 문의 \n이메일 - dongha@metacomedy.net \n인스타 - donghahahaha DM'}, 'country': 'KR'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UU_VSHnyAnKnljt3iMYd8H3w'}}, 'statistics': {'viewCount': '215416911', 'subscriberCount': '337000', 'hiddenSubscriberCount': False, 'videoCount': '512'}, 'topicDetails': {'topicIds': ['/m/09kqc', '/m/02jjt', '/m/02vxn'], 'topicCategories': ['https://en.wikipedia.org/wiki/Humour', 'https://en.wikipedia.org/wiki/Entertainment', 'https://en.wikipedia.org/wiki/Film']}, 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified', 'madeForKids': False}, 'brandingSettings': {'channel': {'title': '동하하', 'description': '놀림전문가\n\n섭외 문의 \n이메일 - dongha@metacomedy.net \n인스타 - donghahahaha DM', 'keywords': '코미디언 스탠드업코미디 유머 웃음 standupcomedy 코미디 동하하 김동하 MC 코미꼬 서울코미디클럽 애드립 대니초 송하빈 이제규 원라이너 호스트 입담 애드립 크라우드워크 김동하 동하하', 'unsubscribedTrailer': 'ETNC0qtCglY', 'country': 'KR'}, 'image': {'bannerExternalUrl': 'https://yt3.googleusercontent.com/UF9KHeVdH6vPd_Yk-bY9z_I1rqSxKyqkAq1j5wS1GKIW9h40E4eHdUaNST-XG5gsk_221z8Y4g'}}}]}
# {'kind': 'youtube#channelListResponse', 'etag': 'BRDWzJxOw8Zy6y8_JC7_wmOPpM8', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'Sv3RvqvrNe4cCehuvPGlZ5pRZOM', 'id': 'UC-OcDPFxfY9Hhdf5P9zq7-A', 'snippet': {'title': '메타코미디클럽', 'description': "Metacomedy Originals\n*메타코미디클럽 홍대 OPEN, 서울특별시 마포구 와우산로 76-1 2층\n네이버에서 '메타코미디클럽 홍대'를 검색하세요\n예약하러 가기 https://booking.naver.com/booking/12/bizes/1037135\n", 'customUrl': '@metacomedyclub', 'publishedAt': '2022-06-10T08:40:26.744491Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/fTdpw7V2KdPaJVG0Kpm3D7v9-wW5CeUhc9KvaQWO5Z2fnHN7CQ8INDsyMvj5wo9QmdDWbbJ21Q=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/fTdpw7V2KdPaJVG0Kpm3D7v9-wW5CeUhc9KvaQWO5Z2fnHN7CQ8INDsyMvj5wo9QmdDWbbJ21Q=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/fTdpw7V2KdPaJVG0Kpm3D7v9-wW5CeUhc9KvaQWO5Z2fnHN7CQ8INDsyMvj5wo9QmdDWbbJ21Q=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': '메타코미디클럽', 'description': "Metacomedy Originals\n*메타코미디클럽 홍대 OPEN, 서울특별시 마포구 와우산로 76-1 2층\n네이버에서 '메타코미디클럽 홍대'를 검색하세요\n예약하러 가기 https://booking.naver.com/booking/12/bizes/1037135\n"}, 'country': 'KR'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UU-OcDPFxfY9Hhdf5P9zq7-A'}}, 'statistics': {'viewCount': '616572435', 'subscriberCount': '788000', 'hiddenSubscriberCount': False, 'videoCount': '400'}, 'topicDetails': {'topicIds': ['/m/02vxn', '/m/02jjt'], 'topicCategories': ['https://en.wikipedia.org/wiki/Film', 'https://en.wikipedia.org/wiki/Entertainment']}, 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified', 'madeForKids': False}, 'brandingSettings': {'channel': {'title': '메타코미디클�
s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AIdro_ny3_7x7wGswXASawBIme4eazHVZAFR_3Dt-gw6p_zBu9c=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': '유병재', 'description': ''}, 'country': 'KR'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUHw9p667e9l0qoYfY8calaA'}}, 'statistics': {'viewCount': '439888676', 'subscriberCount': '1420000', 'hiddenSubscriberCount': False, 'videoCount': '445'}, 'topicDetails': {'topicIds': ['/m/02jjt', '/m/02vxn'], 'topicCategories': ['https://en.wikipedia.org/wiki/Entertainment', 'https://en.wikipedia.org/wiki/Film']}, 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified', 'madeForKids': False}, 'brandingSettings': {'channel': {'title': '유병재', 'keywords': '유병재 코미디 웹예능 문상훈 유규선 kcontents 문학의밤 웃참 고독한 hannipham', 'unsubscribedTrailer': 'oAnfayZJUO8', 'country': 'KR'}, 'image': {'bannerExternalUrl': 'https://yt3.googleusercontent.com/QaONiNJn0emfqZbxck5m32FfAJ6wPCAEuBot7f2ynqN8-_-0r40bjc9LaWljjKw76jmvLkt2'}}}]}
# {'kind': 'youtube#channelListResponse', 'etag': 'BEOf_Efu-EcErI4anSQjL7kFnd0', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': '3mhMMzNlpRrBvzSZN7zdIa6JOHY', 'id': 'UCUj6rrhMTR9pipbAWBAMvUQ', 'snippet': {'title': '침착맨', 'description': '반갑습니다. 오늘도 즐거운 날입니다.', 'customUrl': '@chimchakman_official', 'publishedAt': '2014-09-30T07:40:14Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/Vaomx_a8Qs9bDHS09zsQBB8BG5rY3LWnvb0zcK4oqThz7oT4PCeZQYyMSsQLGh8pmAwlVAmYew=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/Vaomx_a8Qs9bDHS09zsQBB8BG5rY3LWnvb0zcK4oqThz7oT4PCeZQYyMSsQLGh8pmAwlVAmYew=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/Vaomx_a8Qs9bDHS09zsQBB8BG5rY3LWnvb0zcK4oqThz7oT4PCeZQYyMSsQLGh8pmAwlVAmYew=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': '침착맨', 'description': '반갑습니다. 오늘도 즐거운 날입니다.'}, 'country': 'KR'}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUUj6rrhMTR9pipbAWBAMvUQ'}}, 'statistics': {'viewCount': '3122388846', 'subscriberCount': '2720000', 'hiddenSubscriberCount': False, 'videoCount': '7474'}, 'topicDetails': {'topicIds': ['/m/019_rr'], 'topicCategories': ['https://en.wikipedia.org/wiki/Lifestyle_(sociology)']}, 'status': {'privacyStatus': 'public', 'isLinked': True, 'longUploadsStatus': 'longUploadsUnspecified'}, 'brandingSettings': {'channel': {'title': '침착맨', 'description': '반갑습니다. 오늘도 즐거운 날입니다.', 'keywords': '침착맨 침투부', 'country': 'KR'}, 'image': {'bannerExternalUrl': 'https://yt3.googleusercontent.com/ilfjh2eX93KGmCrp7Dkkoqx64YimWIHDSMH1EnWSyzoQbZ0unZq6GWS3FPdFex6x-efArBS8YQ'}}}]}

# %%
df_c = pd.DataFrame(result)
df_c = df_c.reset_index()

# %%
df_c.columns = columns_name

# %%
df_c
# Out:
#    id     name            DisplayName                       uId  \
# 0   0      동하하          @donghahahaha  UC_VSHnyAnKnljt3iMYd8H3w
# 1   1  메타코미디클럽        @metacomedyclub  UC-OcDPFxfY9Hhdf5P9zq7-A
# 2   2      대니초        @dannychocomedy  UCYbPbleb4IFkxeZZRnnScvQ
# 3   3     원라이너       @one_liner_comic  UCYgbhGpTH5dmVy7y4fQd2sw
# 4   4      유병재       @KoreanCryingGuy  UCHw9p667e9l0qoYfY8calaA
# 5   5      침착맨  @ChimChakMan_Official  UCUj6rrhMTR9pipbAWBAMvUQ
#
#            title                                        description  \
# 0            동하하  놀림전문가\n\n섭외 문의 \n이메일 - dongha@metacomedy.net \...
# 1        메타코미디클럽  Metacomedy Originals\n*메타코미디클럽 홍대 OPEN, 서울특별시 ...
# 2  Danny Cho 대니초  I JUST WANT TO PUT UP THE RANDOM THINGS ON MY ...
# 3           원라이너            Comedian\n\n\n\noneliner@metacomedy.net
# 4            유병재
# 5            침착맨                               반갑습니다. 오늘도 즐거운 날입니다.
#
#                    publishedAt  \
# 0         2012-08-18T09:35:10Z
# 1  2022-06-10T08:40:26.744491Z
# 2         2009-03-08T00:28:28Z
# 3         2014-06-05T02:20:29Z
# 4         2011-05-15T18:19:38Z
# 5         2014-09-30T07:40:14Z
#
#                                           thumbnails   viewCount  \
# 0  https://yt3.ggpht.com/XiAkIp5pc-l0I6tzZpbQeZr2...   215416911
# 1  https://yt3.ggpht.com/fTdpw7V2KdPaJVG0Kpm3D7v9...   616572435
# 2  https://yt3.ggpht.com/h1_JMBTXq2J8qrEr-adVFBRA...   127920526
# 3  https://yt3.ggpht.com/_G5gsTmij0dtJZsYSjfgiREx...    50026606
# 4  https://yt3.ggpht.com/ytc/AIdro_ny3_7x7wGswXAS...   439888676
# 5  https://yt3.ggpht.com/Vaomx_a8Qs9bDHS09zsQBB8B...  3122388846
#
#   subscriberCount videoCount  \
# 0          337000        512
# 1          788000        400
# 2          315000        347
# 3          150000        117
# 4         1420000        445
# 5         2720000       7474
#
#                                      topicCategories    dataTime
# 0  [https://en.wikipedia.org/wiki/Humour, https:/...  2025-02-02
# 1  [https://en.wikipedia.org/wiki/Film, https://e...  2025-02-02
# 2  [https://en.wikipedia.org/wiki/Humour, https:/...  2025-02-02
# 3  [https://en.wikipedia.org/wiki/Entertainment, ...  2025-02-02
# 4  [https://en.wikipedia.org/wiki/Entertainment, ...  2025-02-02
# 5  [https://en.wikipedia.org/wiki/Lifestyle_(soci...  2025-02-02

# %%
query = f'SELECT * FROM public."Channel"'
df = pd.read_sql(query, engine)

# %%
df_c_f = pd.concat([df, df_c])

# %%
df_c_f
# Out:
#     id     name            DisplayName                       uId  \
# 0    0     피식대학                  @피식대학  UCGX5sP4ehBkihHwt5bs5wvg
# 1    1     싱글벙글                  @SGBG  UC7_CFRfhIj-fSk3patOQOaw
# 2    2     승우아빠                @swab85  UCgsffS7MfKL6YU3r_U3E-aA
# 3    3      고누리                @konuri  UCs0P4GrXEumyYn-d8ASrGlA
# 4    4      가요이                 @Yoiki  UC8TxOmxwC8QpHRZra7sOFig
# 5    5      너덜트               @NERDULT  UCXEKwWflysXu312NmIP_dlw
# 6    6      동하하          @donghahahaha  UC_VSHnyAnKnljt3iMYd8H3w
# 7    7      곽튜브                @JBKWAK  UClRNDVO8093rmRTtLe4GEPw
# 8    8     기안84               @geean84  UC1Rz7a_DWtsE9cQwSyElE0Q
# 9    9     카더정원         @carthejungwon  UCA6Z6cF3orXMmdeCPUH1-NA
# 10  10      대니초        @dannychocomedy  UCYbPbleb4IFkxeZZRnnScvQ
# 11  11     원라이너       @one_liner_comic  UCYgbhGpTH5dmVy7y4fQd2sw
# 12  12      유병재       @KoreanCryingGuy  UCHw9p667e9l0qoYfY8calaA
# 13  13      침착맨  @ChimChakMan_Official  UCUj6rrhMTR9pipbAWBAMvUQ
# 14  14  메타코미디클럽        @metacomedyclub  UC-OcDPFxfY9Hhdf5P9zq7-A
# 0    0      동하하          @donghahahaha  UC_VSHnyAnKnljt3iMYd8H3w
# 1    1  메타코미디클럽        @metacomedyclub  UC-OcDPFxfY9Hhdf5P9zq7-A
# 2    2      대니초        @dannychocomedy  UCYbPbleb4IFkxeZZRnnScvQ
# 3    3     원라이너       @one_liner_comic  UCYgbhGpTH5dmVy7y4fQd2sw
# 4    4      유병재       @KoreanCryingGuy  UCHw9p667e9l0qoYfY8calaA
# 5    5      침착맨  @ChimChakMan_Official  UCUj6rrhMTR9pipbAWBAMvUQ
#
#              title                                        description  \
# 0   피식대학Psick Univ  코미디 인재 육성 및 연구의 메카 피식대학 \n\n✅ 피식대학 비즈니스 메일\nps...
# 1        싱글벙글 SGBG  #싱글벙글 #스케치코미디\n\n비즈니스 메일 : sgbgstudio@naver.co...
# 2             승우아빠  눈으로 보기만 할수 있는 채널이 아닌, \n그냥 스쳐 지나가는 어려운 레시피가 아닌...
# 3              고누리  만화 그림 열심히 하겠습니다.\n모든 문의: konuri2023@gmail.com\...
# 4    가요이 키우기 YoiKi                               그냥 가영이가 귀여워서 만든 채널\n
# 5              너덜트            문의는 메일로 부탁드립니다 :)\nnerdult1@gmail.com\n
# 6              동하하  놀림전문가\n\n섭외 문의 \n이메일 - dongha@metacomedy.net \...
# 7              곽튜브  세계여행 및 음식탐방을 목표로 하는 채널입니다.\n문의 \ninsta : @jbkw...
# 8             인생84  남극의 황제 펭귄이  \n먹이를 소화시켜 자식에게\n펭귄 밀크를 토 해내듯,\n저 ...
# 9             카더정원     카더가든이다ㅋ\n\n비즈니스 문의 : carthejungwon@gmail.com\n
# 10   Danny Cho 대니초  I JUST WANT TO PUT UP THE RANDOM THINGS ON MY ...
# 11            원라이너            Comedian\n\n\n\noneliner@metacomedy.net
# 12             유병재
# 13             침착맨                               반갑습니다. 오늘도 즐거운 날입니다.
# 14         메타코미디클럽  Metacomedy Originals\n*메타코미디클럽 홍대 OPEN, 서울특별시 ...
# 14                    NaN                     NaN         NaN
# 0                     NaN                     NaN         NaN
# 1                     NaN                     NaN         NaN
# 2                     NaN                     NaN         NaN
# 3                     NaN                     NaN         NaN
# 4                     NaN                     NaN         NaN
# 5                     NaN                     NaN         NaN

# %%
df_c_f = df_c_f.drop_duplicates(subset=['name'])

# %%
df_c_f.id = [x for x in range(len(df_c_f))]
# Out:
# /tmp/ipykernel_1226593/1440078477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_c_f.id = [x for x in range(len(df_c_f))]

# %%
df_c_f.head(5)
# Out:
#    id  name DisplayName                       uId           title  \
# 0   0  피식대학       @피식대학  UCGX5sP4ehBkihHwt5bs5wvg  피식대학Psick Univ
# 1   1  싱글벙글       @SGBG  UC7_CFRfhIj-fSk3patOQOaw       싱글벙글 SGBG
# 2   2  승우아빠     @swab85  UCgsffS7MfKL6YU3r_U3E-aA            승우아빠
# 3   3   고누리     @konuri  UCs0P4GrXEumyYn-d8ASrGlA             고누리
# 4   4   가요이      @Yoiki  UC8TxOmxwC8QpHRZra7sOFig   가요이 키우기 YoiKi
#
#                                          description  \
# 0  코미디 인재 육성 및 연구의 메카 피식대학 \n\n✅ 피식대학 비즈니스 메일\nps...
# 1  #싱글벙글 #스케치코미디\n\n비즈니스 메일 : sgbgstudio@naver.co...
# 2  눈으로 보기만 할수 있는 채널이 아닌, \n그냥 스쳐 지나가는 어려운 레시피가 아닌...
# 3  만화 그림 열심히 하겠습니다.\n모든 문의: konuri2023@gmail.com\...
# 4                               그냥 가영이가 귀여워서 만든 채널\n
#
#                    publishedAt  \
# 0         2019-04-01T05:31:41Z
# 1  2020-12-09T16:00:17.091894Z
# 2         2015-03-05T09:36:17Z
# 3         2013-02-26T14:31:16Z
# 4         2019-04-21T08:47:27Z
#
#                                           thumbnails   viewCount  \
# 0  https://yt3.ggpht.com/FQ61Pjh2In6lt-nd0o6EtWyC...  2179523566
# 1  https://yt3.ggpht.com/NMese3xj7Q6k4GyetZmY5Av_...  1891782093
# 2  https://yt3.ggpht.com/ytc/AIdro_m1ykZ7T3H8P28_...   726724589
# 3  https://yt3.ggpht.com/Ah40-jjuxkgc6FTTWz5EB-th...  1339524809
# 4  https://yt3.ggpht.com/PyMpGNCwvxsYreOBWv3Z5jYR...   425465686
#
#   subscriberCount videoCount  \
# 0         2810000       1776
# 1         1430000        686
# 2         1440000       1238
# 3         2650000        861
# 4          736000        247
#
#                                      topicCategories    dataTime  \
# 0              {https://en.wikipedia.org/wiki/Sport}  2025-01-25
# 1  {https://en.wikipedia.org/wiki/Entertainment,h...  2025-01-25
# 2  {https://en.wikipedia.org/wiki/Lifestyle_(soci...  2025-01-25
# 3  {https://en.wikipedia.org/wiki/Entertainment,h...  2025-01-25
# 4  {https://en.wikipedia.org/wiki/Lifestyle_(soci...  2025-01-25
#
#    LiveBroadcastingCount  LiveBroadcastingViewer    Donation
# 0                   20.0                  1242.0  16302453.0
# 1                    0.0                     0.0         0.0
# 2                   60.0                  2713.0  20207400.0
# 3                  660.0                   241.0  89929994.0
# 4                   24.0                   957.0   6285369.0

# %%
table_name = "Channel"  # 저장할 테이블 이름
df_c_f.to_sql(table_name, engine, if_exists="replace", index=False)
# Out:
# 15

# %% [markdown]
# ### Video

# %%
columns_name = ['channel_id', 'vId','videoTitle', 'videoDescription', 'videoPublishedAt', 'videoThumbnails', 'tags', 'categoryId', 'liveBroadcastContent', 'videoViewCount', 'videoLikeCount', 'videoDislikeCount', 'commentCount', 'topicDetails', 'hasPaidProductPlacement']

# %%
result = []
for channel in zip(channel_lst):
    channel_id = df_c_f[df_c_f['DisplayName'] == '@'+channel[0]]
    channel_id = channel_id['id'].values[0]

    files = os.listdir(channel[0])
    files = [x for x in files if x.find('video_') != -1]
    for f in files:
        with open('./'+ channel[0] + '/' + f, 'r', encoding='utf-8') as file:
            data = json.load(file)
        # print(data)
        itmes = data['items']
        vId = itmes[0]['id']
        try:
            videoTitle = itmes[0]['snippet']['title']
        except:
            print(file)
            continue
        videoDescription = itmes[0]['snippet']['description']
        videoPublishedAt = itmes[0]['snippet']['publishedAt']
        videoThumbnails = itmes[0]['snippet']['thumbnails']['default']['url']
        tags = itmes[0]['snippet'].get('tags')
        categoryId = itmes[0]['snippet']['categoryId']
        liveBroadcastContent = itmes[0]['snippet']['liveBroadcastContent']
        videoViewCount = itmes[0]['statistics'].get('viewCount')
        videoLikeCount = itmes[0]['statistics'].get('likeCount')
        # print(videoLikeCount)
        videoDislikeCount = itmes[0]['statistics'].get('dislikeCount')
        commentCount = itmes[0]['statistics'].get('commentCount')
        topicDetails = itmes[0].get('topicDetails')
        if topicDetails:
            topicDetails = topicDetails['topicCategories']
        
        hasPaidProductPlacement = itmes[0]['paidProductPlacementDetails']['hasPaidProductPlacement']
            
        result.append([channel_id, vId, videoTitle, videoDescription, videoPublishedAt, videoThumbnails, tags,
                       categoryId, liveBroadcastContent, videoViewCount, videoLikeCount, 
                       videoDislikeCount, commentCount, topicDetails, hasPaidProductPlacement])
# Out:
# <_io.TextIOWrapper name='./ChimChakMan_Official/video_UMLzN7QmCDQ.json' mode='r' encoding='utf-8'>

# %%
df_v = pd.DataFrame(result, columns=columns_name)

# %%
df_v = df_v.sort_values(['channel_id', 'videoPublishedAt'])

# %%
len(df_v)
# Out:
# 2035

# %%
df_v.columns
# Out:
# Index(['channel_id', 'vId', 'videoTitle', 'videoDescription',
#        'videoPublishedAt', 'videoThumbnails', 'tags', 'categoryId',
#        'liveBroadcastContent', 'videoViewCount', 'videoLikeCount',
#        'videoDislikeCount', 'commentCount', 'topicDetails',
#        'hasPaidProductPlacement'],
#       dtype='object')

# %%
df_v.value_counts('hasPaidProductPlacement')
# Out:
# hasPaidProductPlacement
# False    1938
# True       97
# Name: count, dtype: int64

# %%
df_v[df_v['vId'] == '0K22_uY-EBc']
# Out:
#       channel_id          vId            videoTitle videoDescription  \
# 1073          10  0K22_uY-EBc  변태 아저씨 Part2 #Shorts  여기는 밤꽃 냄새 날뜻...
#
#           videoPublishedAt                                 videoThumbnails  \
# 1073  2021-04-22T06:12:51Z  https://i.ytimg.com/vi/0K22_uY-EBc/default.jpg
#
#       tags categoryId liveBroadcastContent videoViewCount videoLikeCount  \
# 1073  None         24                 none         484037           3180
#
#      videoDislikeCount commentCount topicDetails  hasPaidProductPlacement
# 1073              None           71         None                    False

# %%
query = f'SELECT * FROM public."Video"'
df = pd.read_sql(query, engine)

# %%
df.columns
# Out:
# Index(['channel_id', 'vId', 'videoTitle', 'videoDescription',
#        'videoPublishedAt', 'videoThumbnails', 'tags', 'categoryId',
#        'videoViewCount', 'videoLikeCount', 'commentCount', 'topicDetails',
#        'hasPaidProductPlacement', 'videoShareCount', 'videoCTR', 'videoAPV',
#        'subscriberViewedRatio', 'videoDislikeCount'],
#       dtype='object')

# %%
df_v.to_sql('Video', engine, if_exists="replace", index=False)
# Out:
# 191

# %% [markdown]
# ### Comments

# %%
channel_name
# Out:
# ['동하하', '메타코미디클럽', '대니초', '원라이너', '유병재', '침착맨']

# %%
columns_name = ['channelName','vId', 'cId', 'textDisplay', 'authorDisplayName', 'likeCount', 'commentPublishedAt', 'commentUpdatedAt', 'replyCount', 'replies']

# %%
result = []
for name, channel in zip(channel_name, channel_lst):
    files = os.listdir(channel)
    files = [x for x in files if x.find('comment_') != -1]
    for f in files:
        try:
            with open('./'+ channel + '/' + f, 'r', encoding='utf-8') as file:
                data = json.load(file)
        except:
            continue
        itmes = data['items']
        
        for item in itmes:
            vId = item['snippet']['videoId']
            cId = item['id']
            
            textDisplay = item['snippet']['topLevelComment']['snippet']['textDisplay']
            authorDisplayName = item['snippet']['topLevelComment']['snippet']['authorDisplayName']
            likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']
            commentPublishedAt = item['snippet']['topLevelComment']['snippet']['publishedAt']
            commentUpdatedAt = item['snippet']['topLevelComment']['snippet']['updatedAt']
            replyCount = item['snippet']['totalReplyCount']
            
            replies_lst = item.get('replies')
            if replies_lst:
                replies = [[str(x['snippet']['textDisplay'].replace('\n', ' ').replace('\r', ' ')), x['snippet']['authorDisplayName']] for x in replies_lst['comments']]
            else:
                replies = None
                
            result.append([name, vId, cId, textDisplay, authorDisplayName, likeCount, commentPublishedAt, commentUpdatedAt, replyCount, str(replies)])

# %%
len(result)
# Out:
# 247345

# %%
df_co = pd.DataFrame(result, columns=columns_name)

# %%
df_co = df_co.sort_values(['vId', 'likeCount'], ascending=False)

# %%
len(df_co)
# Out:
# 247345

# %%
df_co.head(3)
# Out:
#        channelName          vId                         cId  \
# 228035         침착맨  zz3z3mpi5is  UgyqwZXMMDWsT7QLun94AaABAg
# 228036         침착맨  zz3z3mpi5is  UgxYvmKwbUK-h3tmMJN4AaABAg
# 228034         침착맨  zz3z3mpi5is  UgwBDmwZhpH9013SGB94AaABAg
#
#                                        textDisplay authorDisplayName  \
# 228035                      스윙스랑 신용재 나왔는데 왜 노래를 안함  @thunderdoop8340
# 228036            윤남노 셰프님 힌남노 태풍 왔을 때 놀림 많이 받으셧나요?  @user-ou3rq2dn9k
# 228034  왜 레전드 식당들은 문을 닫는가?(&#39;그 카페&#39; 말하는거 아님)         @do-hl6vk
#
#         likeCount    commentPublishedAt      commentUpdatedAt  replyCount  \
# 228035      20545  2024-10-13T10:23:09Z  2024-10-13T10:23:32Z         132
# 228036      13177  2024-10-13T10:04:57Z  2024-10-13T10:04:57Z          54
# 228034      11242  2024-10-13T10:03:23Z  2024-10-13T10:03:23Z          87
#
#                                                   replies
# 228035  [['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ', '@kimdusic'], ['엌ㅋㅋㅋㅋㅋㅋ', ...
# 228036  [['올려 ㅋㅋㅋㅋ', '@유튜브끊는다'], ['ㅅㅂㅋㅋㅋㅋㅋㅋㅋ', '@양세훈세훈...
# 228034  [['특히 카페가 그런듯 (그 카페 아님)', '@user-os4df9xw3f'],...

# %%
df_co.loc[81673,:]
# Out:
# channelName                                                        원라이너
# vId                                                         -1Ow4gAe0zc
# cId                                          UgxJs14CHqxIQUYPWXV4AaABAg
# textDisplay           진짜 너무 정리를 잘해줘서 할 말을 잃을지경.\r<br>같은 한국인으로서, 난 진짜...
# authorDisplayName                                               @kjh222
# likeCount                                                            10
# commentPublishedAt                                 2022-06-12T02:34:37Z
# commentUpdatedAt                                   2022-06-12T02:34:37Z
# replyCount                                                            3
# replies               [['무한도전에도 시애미질 하는 나란데요 뭐.. ㅋㅋ', '@100가-v5o'], ...
# Name: 81673, dtype: object

# %%
df_co['vId'] = [str(x) for x in df_co['vId']]
df_co['textDisplay'] = [str(x.replace('\n', ' ')) for x in df_co['textDisplay']]
df_co['textDisplay'] = [str(x.replace('\r', ' ')) for x in df_co['textDisplay']]

# %%
df_co.loc[81673,:]
# Out:
# channelName                                                        원라이너
# vId                                                         -1Ow4gAe0zc
# cId                                          UgxJs14CHqxIQUYPWXV4AaABAg
# textDisplay           진짜 너무 정리를 잘해줘서 할 말을 잃을지경. <br>같은 한국인으로서, 난 진짜 ...
# authorDisplayName                                               @kjh222
# likeCount                                                            10
# commentPublishedAt                                 2022-06-12T02:34:37Z
# commentUpdatedAt                                   2022-06-12T02:34:37Z
# replyCount                                                            3
# replies               [['무한도전에도 시애미질 하는 나란데요 뭐.. ㅋㅋ', '@100가-v5o'], ...
# Name: 81673, dtype: object

# %%
df_co.to_csv('review_v2.csv', encoding='utf-8-sig')

# %%
df_co.to_sql('Comments', engine, if_exists="replace", index=False)
# Out:
# 109

# %%
query = f'SELECT * FROM public."Comments"'
comments_df = pd.read_sql(query, engine)

# %%
for _, row in comments_df.iterrows():
    print(eval(row['replies']))
    break
# Out:
# [['에세 새로 나온거나 펴야지 ㄸㅂ..', '@김-f1w'], ['가자..', '@화정동레킹볼'], ['전담핀다', '@merem5336'], ['가즈아. .   신기루같은거야', '@donrich5908'], ['두개 연짝으로 피고옴', '@키데니']]
